# %%
from albumentations import HorizontalFlip,Compose,BboxParams

# %%
import torch
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_path = "/Users/matsunaganaoki/Desktop/DeepLearning/data/BBox/image-rabitt.jpg"
label_path = "/Users/matsunaganaoki/Desktop/DeepLearning/data/BBox/image-rabitt.txt"

# %%
img = cv2.imread(img_path)
plt.imshow(img)

# %%
def draw_bbox(img,bbox):
    h,w,c = img.shape
    p1 = int((bbox[0]-bbox[2]/2)*w), int((bbox[1]-bbox[3]/2) * h)
    p2 = int((bbox[0]+bbox[2]/2)* w), int((bbox[1]+bbox[3]/2)* h)
    print(p1)
    print(p2)
    cv2.rectangle(img,p1,p2,(255,255,255),10)
    return img

# %%
with open(label_path) as f:
    _,x0,y0,x1,y1 = f.read().split()
    bbox = [float(x0),float(y0),float(x1),float(y1)]
print(bbox)
# Out:
# [0.289062, 0.536806, 0.385937, 0.823611]

# %%
box_image = draw_bbox(img,bbox)
# Out:
# (122, 90)
# (616, 683)

# %%
img.shape
# Out:
# (720, 1280, 3)

# %%
plt.imshow(box_image)

# %%
H = HorizontalFlip()

# %%
BOX_COLOR = (255, 0, 0)
def visualize_bbox(img, bbox, class_id, class_idx_to_name, color=BOX_COLOR, thickness=2):
    x_min, y_min, w, h = bbox
    x_min, x_max, y_min, y_max = int(x_min), int(x_min + w), int(y_min), int(y_min + h)
    cv2.rectangle(img, (x_min, y_min), (x_max, y_max), color=color, thickness=thickness)
    class_name = class_idx_to_name[class_id]
    ((text_width, text_height), _) = cv2.getTextSize(class_name, cv2.FONT_HERSHEY_SIMPLEX, 0.35, 1)    
    cv2.rectangle(img, (x_min, y_min - int(1.3 * text_height)), (x_min + text_width, y_min), BOX_COLOR, -1)
    cv2.putText(img, class_name, (x_min, y_min - int(0.3 * text_height)), cv2.FONT_HERSHEY_SIMPLEX, 0.35,TEXT_COLOR, lineType=cv2.LINE_AA)
    return img

def visualize(annotations, category_id_to_name):
    img = annotations['image'].copy()
    for idx, bbox in enumerate(annotations['bboxes']):
        img = visualize_bbox(img, bbox, annotations['category_id'][idx], category_id_to_name)
    plt.figure(figsize=(12, 12))
    plt.imshow(img)

# %%
def get_aug(aug, min_area=0., min_visibility=0.):
    return Compose(aug, bbox_params=BboxParams(format='coco', min_area=min_area, 
                                               min_visibility=min_visibility, label_fields=['category_id']))

# %%
aug = get_aug([HorizontalFlip(p=1)])
augmented = aug(**annotations)
visualize(augmented, category_id_to_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-28dd5a60956a> in <module>
#       1 aug = get_aug([HorizontalFlip(p=1)])
# ----> 2 augmented = aug(**annotations)
#       3 visualize(augmented, category_id_to_name)
#
# NameError: name 'annotations' is not defined
